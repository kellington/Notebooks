# %%
import pandas as pd
import sqlite3

#read the CSV
df = pd.read_csv('/Users/Rob/Projects/Notebooks/data/nyc_schools/sat_results.csv')
#connect to a database
conn = sqlite3.connect("banana.db") #if the db does not exist, this creates a Any_Database_Name.db file in the current directory
#store your table in the database:
df.to_sql('fruit', conn)
#read a SQL Query out of your database and into a pandas dataframe
sql_string = 'SELECT * FROM fruit'
df = pd.read_sql(sql_string, conn)
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py:1201: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %%
#read a SQL Query out of your database and into a pandas dataframe
sql_string = 'SELECT * FROM fruit'
df = pd.read_sql(sql_string, conn)
df
# Out:
#      index     DBN                                        SCHOOL NAME  \
# 0        0  01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1        1  01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2        2  01M450                         EAST SIDE COMMUNITY SCHOOL
# 3        3  01M458                          FORSYTH SATELLITE ACADEMY
# 4        4  01M509                            MARTA VALLE HIGH SCHOOL
# 5        5  01M515            LOWER EAST SIDE PREPARATORY HIGH SCHOOL
# 6        6  01M539  NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND ...
# 7        7  01M650                               CASCADES HIGH SCHOOL
# 8        8  01M696                     BARD HIGH SCHOOL EARLY COLLEGE
# 9        9  02M047  47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECO...
# 10      10  02M288                       FOOD AND FINANCE HIGH SCHOOL
# 11      11  02M294                               ESSEX STREET ACADEMY
# ...

# %%
sql_string = 'SELECT count(*) FROM fruit'
df = pd.read_sql(sql_string, conn)
df
# Out:
#    count(*)
# 0       478

# %%
sql_string = 'SELECT "SCHOOL NAME", "Num of SAT Test Takers" FROM fruit where "Num of SAT Test Takers" = 60'
df = pd.read_sql(sql_string, conn)
df
# Out:
#                                    SCHOOL NAME Num of SAT Test Takers
# 0                    GRAMERCY ARTS HIGH SCHOOL                     60
# 1             CITY COLLEGE ACADEMY OF THE ARTS                     60
# 2                     ASTOR COLLEGIATE ACADEMY                     60
# 3             ACADEMY OF INNOVATIVE TECHNOLOGY                     60
# 4  BROOKLYN COLLEGIATE: A COLLEGE BOARD SCHOOL                     60
